# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
from sklearn.metrics import f1_score 
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Dropout, Conv2D

# %%
# Loads the data required for detecting the license plates from cascade classifier.
plate_cascade = cv2.CascadeClassifier('C:/Users/anime/Downloads/Compressed/archive/indian_license_plate.xml')
# add the path to 'india_license_plate.xml' file.

# %%
def detect_plate(img, text=''): # the function detects and performs blurring on the number plate.
    plate_img = img.copy()
    roi = img.copy()
    plate_rect = plate_cascade.detectMultiScale(plate_img, scaleFactor = 1.3, minNeighbors = 7) # detects numberplates and returns the coordinates and dimensions of detected license plate's contours.
    if plate_img.dtype != np.uint8:
        plate_img = cv2.cvtColor(plate_img, cv2.COLOR_BGR2GRAY)
    for (x,y,w,h) in plate_rect:
        roi_ = roi[y:y+h, x:x+w, :] # extracting the Region of Interest of license plate for blurring.
    
        plate = roi[y:y+h, x:x+w, :]
        cv2.rectangle(plate_img, (x+2,y), (x+w-3, y+h-5), (51,181,155), 3) # finally representing the detected contours by drawing rectangles around the edges.
    if text!='':
        plate_img = cv2.putText(plate_img, text, (x-w//2,y-h//2), 
                                cv2.FONT_HERSHEY_COMPLEX_SMALL , 0.5, (51,181,155), 1, cv2.LINE_AA)
        
    return plate_img, plate # returning the processed image.

# %%
# Testing the above function
def display(img_, title=''):
    img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
    fig = plt.figure(figsize=(10,6))
    ax = plt.subplot(111)
    ax.imshow(img)
    plt.axis('off')
    plt.title(title)
    plt.show()

img = cv2.imread('C:/Users/anime/Downloads/Compressed/archive/NumberPlate.jpg')
display(img, 'input image')

# %%
# Getting plate prom the processed image
output_img, plate = detect_plate(img)

# %%
display(output_img, 'detected license plate in the input image')

# %%
display(plate, 'extracted license plate from the image')

# %%
# Match contours to license plate or character template
def find_contours(dimensions, img) :

    # Find all contours in the image
    cntrs, _ = cv2.findContours(img.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Retrieve potential dimensions
    lower_width = dimensions[0]
    upper_width = dimensions[1]
    lower_height = dimensions[2]
    upper_height = dimensions[3]
    
    # Check largest 5 or  15 contours for license plate or character respectively
    cntrs = sorted(cntrs, key=cv2.contourArea, reverse=True)[:15]
    
    ii = cv2.imread('contour.jpg')
    
    x_cntr_list = []
    target_contours = []
    img_res = []
    for cntr in cntrs :
        # detects contour in binary image and returns the coordinates of rectangle enclosing it
        intX, intY, intWidth, intHeight = cv2.boundingRect(cntr)
        
        # checking the dimensions of the contour to filter out the characters by contour's size
        if intWidth > lower_width and intWidth < upper_width and intHeight > lower_height and intHeight < upper_height :
            x_cntr_list.append(intX) #stores the x coordinate of the character's contour, to used later for indexing the contours

            char_copy = np.zeros((44,24))
            # extracting each character using the enclosing rectangle's coordinates.
            char = img[intY:intY+intHeight, intX:intX+intWidth]
            char = cv2.resize(char, (20, 40))
            
            cv2.rectangle(ii, (intX,intY), (intWidth+intX, intY+intHeight), (50,21,200), 2)
            plt.imshow(ii, cmap='gray')

            # Make result formatted for classification: invert colors
            char = cv2.subtract(255, char)

            # Resize the image to 24x44 with black border
            char_copy[2:42, 2:22] = char
            char_copy[0:2, :] = 0
            char_copy[:, 0:2] = 0
            char_copy[42:44, :] = 0
            char_copy[:, 22:24] = 0

            img_res.append(char_copy) # List that stores the character's binary image (unsorted)
            
    # Return characters on ascending order with respect to the x-coordinate (most-left character first)
            
    plt.show()
    # arbitrary function that stores sorted list of character indeces
    indices = sorted(range(len(x_cntr_list)), key=lambda k: x_cntr_list[k])
    img_res_copy = []
    for idx in indices:
        img_res_copy.append(img_res[idx])# stores character images according to their index
    img_res = np.array(img_res_copy)

    return img_res

# %%
# Find characters in the resulting images
def segment_characters(image) :

    # Preprocess cropped license plate image
    img_lp = cv2.resize(image, (333, 75))
    img_gray_lp = cv2.cvtColor(img_lp, cv2.COLOR_BGR2GRAY)
    _, img_binary_lp = cv2.threshold(img_gray_lp, 200, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    img_binary_lp = cv2.erode(img_binary_lp, (3,3))
    img_binary_lp = cv2.dilate(img_binary_lp, (3,3))

    LP_WIDTH = img_binary_lp.shape[0]
    LP_HEIGHT = img_binary_lp.shape[1]

    # Make borders white
    img_binary_lp[0:3,:] = 255
    img_binary_lp[:,0:3] = 255
    img_binary_lp[72:75,:] = 255
    img_binary_lp[:,330:333] = 255

    # Estimations of character contours sizes of cropped license plates
    dimensions = [LP_WIDTH/6,
                       LP_WIDTH/2,
                       LP_HEIGHT/10,
                       2*LP_HEIGHT/3]
    plt.imshow(img_binary_lp, cmap='gray')
    plt.show()
    cv2.imwrite('contour.jpg',img_binary_lp)

    # Get contours within cropped license plate
    char_list = find_contours(dimensions, img_binary_lp)

    return char_list

# %%
# Let's see the segmented characters
char = segment_characters(plate)

# %%
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(char[i], cmap='gray')
    plt.axis('off')

# %% [markdown]
# ### Model for characters

# %%
import tensorflow.keras.backend as K
train_datagen = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1)
path = "C:/Users/anime/Downloads/Compressed/archive/data/data"
train_generator = train_datagen.flow_from_directory(
        path+'/train',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28
        batch_size=1,
        class_mode='sparse')

validation_generator = train_datagen.flow_from_directory(
        path+'/val',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28 batch_size=1,
        class_mode='sparse')
# Out:
# Found 864 images belonging to 36 classes.
# Found 216 images belonging to 36 classes.

# %%
# Metrics for checking the model performance while training
def f1score(y, y_pred):
  return f1_score(y, tf.math.argmax(y_pred, axis=1), average='micro') 

def custom_f1score(y, y_pred):
  return tf.py_function(f1score, (y, y_pred), tf.double)

# %%
K.clear_session()
model = Sequential()
model.add(Conv2D(16, (22,22), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (16,16), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (8,8), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (4,4), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(36, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=[custom_f1score])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        23248
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        131104
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        131136
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        65600
#
#  max_pooling2d (MaxPooling2D  (None, 7, 7, 64)         0
#  )
#
#  dropout (Dropout)           (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 128)               401536
#
#  dense_1 (Dense)             (None, 36)                4644
#
# =================================================================
# Total params: 757,268
# Trainable params: 757,268
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('F:/LPR/my_model.h5')

# %%
class stop_training_callback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_custom_f1score') > 0.99):
      self.model.stop_training = True

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the model checkpoint callback
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_loss', save_best_only=True, save_weights_only=True, mode='min', verbose=1)

batch_size = 1
callbacks = [stop_training_callback(), checkpoint]  # Add the checkpoint callback

model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator, 
    epochs=80, verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/80
# 864/864 [==============================] - ETA: 0s - loss: 3.2454 - custom_f1score: 0.1493
# Epoch 1: val_loss improved from inf to 2.01453, saving model to model_weights.h5
# 864/864 [==============================] - 35s 39ms/step - loss: 3.2454 - custom_f1score: 0.1493 - val_loss: 2.0145 - val_custom_f1score: 0.4033
# Epoch 2/80
# 864/864 [==============================] - ETA: 0s - loss: 1.3712 - custom_f1score: 0.5903
# Epoch 2: val_loss improved from 2.01453 to 0.72711, saving model to model_weights.h5
# 864/864 [==============================] - 34s 39ms/step - loss: 1.3712 - custom_f1score: 0.5903 - val_loss: 0.7271 - val_custom_f1score: 0.8006
# Epoch 3/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.6715 - custom_f1score: 0.7914
# Epoch 3: val_loss improved from 0.72711 to 0.47986, saving model to model_weights.h5
# 864/864 [==============================] - 34s 39ms/step - loss: 0.6707 - custom_f1score: 0.7917 - val_loss: 0.4799 - val_custom_f1score: 0.8393
# Epoch 4/80
# 864/864 [==============================] - ETA: 0s - loss: 0.4968 - custom_f1score: 0.8553
# Epoch 4: val_loss improved from 0.47986 to 0.28662, saving model to model_weights.h5
# 864/864 [==============================] - 34s 39ms/step - loss: 0.4968 - custom_f1score: 0.8553 - val_loss: 0.2866 - val_custom_f1score: 0.8958
# Epoch 5/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.3555 - custom_f1score: 0.8806
# Epoch 5: val_loss improved from 0.28662 to 0.18008, saving model to model_weights.h5
# 864/864 [==============================] - 35s 40ms/step - loss: 0.3559 - custom_f1score: 0.8808 - val_loss: 0.1801 - val_custom_f1score: 0.9360
# Epoch 6/80
# 864/864 [==============================] - ETA: 0s - loss: 0.2937 - custom_f1score: 0.9086
# Epoch 6: val_loss did not improve from 0.18008
# 864/864 [==============================] - 37s 42ms/step - loss: 0.2937 - custom_f1score: 0.9086 - val_loss: 0.2039 - val_custom_f1score: 0.9390
# Epoch 7/80
# 864/864 [==============================] - ETA: 0s - loss: 0.2193 - custom_f1score: 0.9352
# Epoch 7: val_loss did not improve from 0.18008
# 864/864 [==============================] - 35s 40ms/step - loss: 0.2193 - custom_f1score: 0.9352 - val_loss: 0.2179 - val_custom_f1score: 0.9077
# Epoch 8/80
# 864/864 [==============================] - ETA: 0s - loss: 0.1972 - custom_f1score: 0.9236
# Epoch 8: val_loss improved from 0.18008 to 0.12623, saving model to model_weights.h5
# 864/864 [==============================] - 36s 42ms/step - loss: 0.1972 - custom_f1score: 0.9236 - val_loss: 0.1262 - val_custom_f1score: 0.9539
# Epoch 9/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1514 - custom_f1score: 0.9629
# Epoch 9: val_loss did not improve from 0.12623
# 864/864 [==============================] - 34s 40ms/step - loss: 0.1513 - custom_f1score: 0.9630 - val_loss: 0.1370 - val_custom_f1score: 0.9479
# Epoch 10/80
# 864/864 [==============================] - ETA: 0s - loss: 0.1855 - custom_f1score: 0.9398
# Epoch 10: val_loss did not improve from 0.12623
# 864/864 [==============================] - 37s 43ms/step - loss: 0.1855 - custom_f1score: 0.9398 - val_loss: 0.4566 - val_custom_f1score: 0.8854
# Epoch 11/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1489 - custom_f1score: 0.9571
# Epoch 11: val_loss did not improve from 0.12623
# 864/864 [==============================] - 36s 41ms/step - loss: 0.1487 - custom_f1score: 0.9572 - val_loss: 0.1368 - val_custom_f1score: 0.9613
# Epoch 12/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1395 - custom_f1score: 0.9606
# Epoch 12: val_loss did not improve from 0.12623
# 864/864 [==============================] - 37s 43ms/step - loss: 0.1393 - custom_f1score: 0.9606 - val_loss: 0.1412 - val_custom_f1score: 0.9568
# Epoch 13/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1001 - custom_f1score: 0.9652
# Epoch 13: val_loss improved from 0.12623 to 0.07372, saving model to model_weights.h5
# 864/864 [==============================] - 35s 41ms/step - loss: 0.1000 - custom_f1score: 0.9653 - val_loss: 0.0737 - val_custom_f1score: 0.9732
# Epoch 14/80
# 864/864 [==============================] - ETA: 0s - loss: 0.1139 - custom_f1score: 0.9699
# Epoch 14: val_loss did not improve from 0.07372
# 864/864 [==============================] - 34s 40ms/step - loss: 0.1139 - custom_f1score: 0.9699 - val_loss: 0.1363 - val_custom_f1score: 0.9539
# Epoch 15/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1365 - custom_f1score: 0.9652
# Epoch 15: val_loss did not improve from 0.07372
# 864/864 [==============================] - 34s 40ms/step - loss: 0.1363 - custom_f1score: 0.9653 - val_loss: 0.0828 - val_custom_f1score: 0.9688
# Epoch 16/80
# 864/864 [==============================] - ETA: 0s - loss: 0.1445 - custom_f1score: 0.9560
# Epoch 16: val_loss did not improve from 0.07372
# 864/864 [==============================] - 34s 39ms/step - loss: 0.1445 - custom_f1score: 0.9560 - val_loss: 0.0945 - val_custom_f1score: 0.9673
# Epoch 17/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0587 - custom_f1score: 0.9710
# Epoch 17: val_loss did not improve from 0.07372
# 864/864 [==============================] - 35s 40ms/step - loss: 0.0586 - custom_f1score: 0.9711 - val_loss: 0.0800 - val_custom_f1score: 0.9732
# Epoch 18/80
# 864/864 [==============================] - ETA: 0s - loss: 0.1052 - custom_f1score: 0.9688
# Epoch 18: val_loss improved from 0.07372 to 0.06433, saving model to model_weights.h5
# 864/864 [==============================] - 35s 40ms/step - loss: 0.1052 - custom_f1score: 0.9688 - val_loss: 0.0643 - val_custom_f1score: 0.9643
# Epoch 19/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1162 - custom_f1score: 0.9652
# Epoch 19: val_loss did not improve from 0.06433
# 864/864 [==============================] - 35s 41ms/step - loss: 0.1163 - custom_f1score: 0.9653 - val_loss: 0.5336 - val_custom_f1score: 0.8616
# Epoch 20/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0733 - custom_f1score: 0.9757
# Epoch 20: val_loss improved from 0.06433 to 0.04727, saving model to model_weights.h5
# 864/864 [==============================] - 36s 42ms/step - loss: 0.0732 - custom_f1score: 0.9757 - val_loss: 0.0473 - val_custom_f1score: 0.9777
# Epoch 21/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0837 - custom_f1score: 0.9687
# Epoch 21: val_loss did not improve from 0.04727
# 864/864 [==============================] - 36s 42ms/step - loss: 0.0836 - custom_f1score: 0.9688 - val_loss: 0.1690 - val_custom_f1score: 0.9464
# Epoch 22/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1182 - custom_f1score: 0.9618
# Epoch 22: val_loss did not improve from 0.04727
# 864/864 [==============================] - 37s 42ms/step - loss: 0.1181 - custom_f1score: 0.9618 - val_loss: 0.0993 - val_custom_f1score: 0.9598
# Epoch 23/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0941 - custom_f1score: 0.9780
# Epoch 23: val_loss did not improve from 0.04727
# 864/864 [==============================] - 38s 44ms/step - loss: 0.0941 - custom_f1score: 0.9780 - val_loss: 0.0625 - val_custom_f1score: 0.9821
# Epoch 24/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0571 - custom_f1score: 0.9745
# Epoch 24: val_loss improved from 0.04727 to 0.03094, saving model to model_weights.h5
# 864/864 [==============================] - 35s 40ms/step - loss: 0.0571 - custom_f1score: 0.9745 - val_loss: 0.0309 - val_custom_f1score: 0.9866
# Epoch 25/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0470 - custom_f1score: 0.9815
# Epoch 25: val_loss did not improve from 0.03094
# 864/864 [==============================] - 36s 42ms/step - loss: 0.0470 - custom_f1score: 0.9815 - val_loss: 0.0443 - val_custom_f1score: 0.9807
# Epoch 26/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.1146 - custom_f1score: 0.9757
# Epoch 26: val_loss did not improve from 0.03094
# 864/864 [==============================] - 37s 43ms/step - loss: 0.1144 - custom_f1score: 0.9757 - val_loss: 0.1059 - val_custom_f1score: 0.9554
# Epoch 27/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0544 - custom_f1score: 0.9815
# Epoch 27: val_loss did not improve from 0.03094
# 864/864 [==============================] - 37s 43ms/step - loss: 0.0544 - custom_f1score: 0.9815 - val_loss: 0.0348 - val_custom_f1score: 0.9807
# Epoch 28/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0845 - custom_f1score: 0.9757
# Epoch 28: val_loss did not improve from 0.03094
# 864/864 [==============================] - 35s 41ms/step - loss: 0.0845 - custom_f1score: 0.9757 - val_loss: 0.0630 - val_custom_f1score: 0.9673
# Epoch 29/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0893 - custom_f1score: 0.9745
# Epoch 29: val_loss did not improve from 0.03094
# 864/864 [==============================] - 35s 40ms/step - loss: 0.0893 - custom_f1score: 0.9745 - val_loss: 0.0511 - val_custom_f1score: 0.9792
# Epoch 30/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0651 - custom_f1score: 0.9769
# Epoch 30: val_loss did not improve from 0.03094
# 864/864 [==============================] - 36s 41ms/step - loss: 0.0651 - custom_f1score: 0.9769 - val_loss: 0.0615 - val_custom_f1score: 0.9673
# Epoch 31/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0681 - custom_f1score: 0.9769
# Epoch 31: val_loss did not improve from 0.03094
# 864/864 [==============================] - 38s 44ms/step - loss: 0.0681 - custom_f1score: 0.9769 - val_loss: 0.1288 - val_custom_f1score: 0.9688
# Epoch 32/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0686 - custom_f1score: 0.9780
# Epoch 32: val_loss did not improve from 0.03094
# 864/864 [==============================] - 35s 40ms/step - loss: 0.0686 - custom_f1score: 0.9780 - val_loss: 0.3285 - val_custom_f1score: 0.9182
# Epoch 33/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0825 - custom_f1score: 0.9618
# Epoch 33: val_loss did not improve from 0.03094
# 864/864 [==============================] - 34s 39ms/step - loss: 0.0824 - custom_f1score: 0.9618 - val_loss: 0.0671 - val_custom_f1score: 0.9777
# Epoch 34/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0654 - custom_f1score: 0.9815
# Epoch 34: val_loss did not improve from 0.03094
# 864/864 [==============================] - 34s 39ms/step - loss: 0.0654 - custom_f1score: 0.9815 - val_loss: 0.0585 - val_custom_f1score: 0.9732
# Epoch 35/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0468 - custom_f1score: 0.9838
# Epoch 35: val_loss did not improve from 0.03094
# 864/864 [==============================] - 34s 39ms/step - loss: 0.0467 - custom_f1score: 0.9838 - val_loss: 0.0794 - val_custom_f1score: 0.9688
# Epoch 36/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0393 - custom_f1score: 0.9815
# Epoch 36: val_loss did not improve from 0.03094
# 864/864 [==============================] - 34s 39ms/step - loss: 0.0393 - custom_f1score: 0.9815 - val_loss: 0.0428 - val_custom_f1score: 0.9851
# Epoch 37/80
# 864/864 [==============================] - ETA: 0s - loss: 0.0516 - custom_f1score: 0.9769
# Epoch 37: val_loss did not improve from 0.03094
# 864/864 [==============================] - 34s 40ms/step - loss: 0.0516 - custom_f1score: 0.9769 - val_loss: 0.0761 - val_custom_f1score: 0.9747
# Epoch 38/80
# 863/864 [============================>.] - ETA: 0s - loss: 0.0713 - custom_f1score: 0.9815
# Epoch 38: val_loss improved from 0.03094 to 0.02531, saving model to model_weights.h5
# 864/864 [==============================] - 34s 40ms/step - loss: 0.0712 - custom_f1score: 0.9815 - val_loss: 0.0253 - val_custom_f1score: 0.9911

# %%
# Predicting the output
def fix_dimension(img): 
  new_img = np.zeros((28,28,3))
  for i in range(3):
    new_img[:,:,i] = img
  return new_img
  
def show_results():
    dic = {}
    characters = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i,c in enumerate(characters):
        dic[i] = c

    output = []
    for i,ch in enumerate(char): #iterating over the characters
        img_ = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
        img = fix_dimension(img_)
        img = img.reshape(1,28,28,3) #preparing image for the model
        predictions = model.predict(img)
        y_ = predictions.argmax(axis=-1)[0] #predicting the class
        character = dic[y_] #
        output.append(character) #storing the result in a list
        
    plate_number = ''.join(output)
    
    return plate_number

print(show_results())
# Out:
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# HR2SDK8337

# %%
# Segmented characters and their predicted value.
plt.figure(figsize=(10,6))
for i,ch in enumerate(char):
    img = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
    plt.subplot(3,4,i+1)
    plt.imshow(img,cmap='gray')
    plt.title(f'predicted: {show_results()[i]}')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
plate_number = show_results()
print(plate_number)
plate_img = cv2.convertScaleAbs(plate_img)
output_img, plate = detect_plate(img, plate_number)
display(output_img, 'detected license plate number in the input image')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# HR2SDK8337
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [31], in <cell line: 4>()
#       1 plate_number = show_results()
#       2 print(plate_number)
# ----> 4 output_img, plate = detect_plate(img, plate_number)
#
# Input In [7], in detect_plate(img, text)
#       3 roi = img.copy()
#       4 # Convert the image to 8-bit if not already
# ----> 5 plate_rect = plate_cascade.detectMultiScale(plate_img, scaleFactor = 1.3, minNeighbors = 7) # detects numberplates and returns the coordinates and dimensions of detected license plate's contours.
#       6 for (x,y,w,h) in plate_rect:
#       7     roi_ = roi[y:y+h, x:x+w, :] # extracting the Region of Interest of license plate for blurring.
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1389: error: (-215:Assertion failed) scaleFactor > 1 && _image.depth() == CV_8U in function 'cv::CascadeClassifierImpl::detectMultiScale'
